# %%
import plotly.io as pio
pio.renderers.default="iframe"
import pandas as pd
import sqlite3
from plotly import express as px
from sklearn.linear_model import LinearRegression
import seaborn as sns
from matplotlib import pyplot as plt
import requests
import json
import urllib

# %%
conn = sqlite3.connect("schools.db") # this creates a database called schools.db.

# %%
df_iter = pd.read_csv("All_US_Schools.csv", chunksize = 1000) # reads in our dataframe in digestible chunks of 1000 rows at a time

# %%
for df in df_iter:
    df.to_sql("schools", conn, if_exists = "append", index = False) # writes each chunk of the dataframe into a SQL table

# %%
def query_schools_database(state):
    """
    query_schools_database uses SQL to read through a database containing relevant school district location.

    :state: the name of the state to be investigated
    """
    
    cmd = \
    f"""
    SELECT S.state, S.name, S.lat, S.lon
    FROM schools S
    WHERE S.state = "{state}"
    """
    
    return pd.read_sql_query(cmd, conn)

# %%
df = query_schools_database("AL")

# %%
df
# Out:
#     STATE                    NAME        LAT        LON
# 0      AL  Alabama Youth Services  32.376397 -86.084642
# 1      AL        Albertville City  34.282186 -86.223627
# 2      AL         Marshall County  34.305770 -86.286958
# 3      AL             Hoover City  33.406200 -86.766900
# 4      AL            Madison City  34.686721 -86.745741
# ..    ...                     ...        ...        ...
# 180    AL           Walker County  33.834179 -87.274959
# 181    AL       Washington County  31.465862 -88.257989
# 182    AL           Wilcox County  32.003296 -87.290119
# 183    AL           Winfield City  33.933197 -87.811801
# 184    AL          Winston County  34.146071 -87.402788
#
# [185 rows x 4 columns]

# %%
fig = px.scatter_mapbox(df, lat='LAT', lon='LON', zoom=1, mapbox_style='carto-positron', hover_name='NAME')

# %%
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_23.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
prof_df = pd.read_csv("prof.csv", header=None)
# Out:
# C:\Users\jimmy\AppData\Local\Temp\ipykernel_21456\3699358574.py:1: DtypeWarning:
#
# Columns (0,2,7,8) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
prof_df.columns = prof_df.iloc[4]

# %%
prof_df
# Out:
# 4      System Code                            System Name  School Code  \
# 0              NaN  ALABAMA STATE DEPARTMENT OF EDUCATION          NaN
# 1              NaN                                    NaN          NaN
# 2              NaN                                    NaN          NaN
# 3              NaN                                    NaN          NaN
# 4      System Code                            System Name  School Code
# ...            ...                                    ...          ...
# 75288          810          Magic City Acceptance Academy           10
# 75289          810          Magic City Acceptance Academy           10
# 75290          810          Magic City Acceptance Academy           10
# 75291          810          Magic City Acceptance Academy           10
# 75292          810          Magic City Acceptance Academy           10
#
# 4                        School Name  Subject  \
# 0                                NaN      NaN
# 1                                NaN      NaN
# 2                                NaN      NaN
# 3                                NaN      NaN
# 4                        School Name  Subject
# ...                              ...      ...
# 75288  Magic City Acceptance Academy      ELA
# 75289  Magic City Acceptance Academy     Math
# 75290  Magic City Acceptance Academy     Math
# 75291  Magic City Acceptance Academy     Math
# 75292  Magic City Acceptance Academy     Math
#
# 4                                   Test Type  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                   Test Type
# ...                                       ...
# 75288  Regular Assessment With Accommodations
# 75289  Regular Assessment With Accommodations
# 75290  Regular Assessment With Accommodations
# 75291  Regular Assessment With Accommodations
# 75292  Regular Assessment With Accommodations
#
# 4                                                  Grade  \
# 0      Assessment Participation and Proficiency of St...
# 1                                                      *
# 2                                                Subject
# 3                                                 Source
# 4                                                  Grade
# ...                                                  ...
# 75288                                                ALL
# 75289                                                 06
# 75290                                                 07
# 75291                                                 08
# 75292                                                ALL
#
# 4                      ALL Category Only ***% Proficient  \
# 0                                                    NaN
# 1      Indicates that the number of students was <= 1...
# 2                                           Math and ELA
# 3                  Annual Student Assessment (2021-2022)
# 4                      ALL Category Only ***% Proficient
# ...                                                  ...
# 75288                                               37.5
# 75289                                                NaN
# 75290                                                NaN
# 75291                                                NaN
# 75292                                               12.5
#
# 4      Percent Of All Students Tested  Total Students Tested  ...  NaN  NaN  \
# 0                                 NaN                    NaN  ...  NaN  NaN
# 1                                 NaN                    NaN  ...  NaN  NaN
# 2                                 NaN                    NaN  ...  NaN  NaN
# 3                                 NaN                    NaN  ...  NaN  NaN
# 4      Percent Of All Students Tested  Total Students Tested  ...  NaN  NaN
# ...                               ...                    ...  ...  ...  ...
# 75288                            6.11                      *  ...  NaN  NaN
# 75289                            8.33                      *  ...  NaN  NaN
# 75290                            6.98                      *  ...  NaN  NaN
# 75291                            5.88                      *  ...  NaN  NaN
# 75292                            6.06                      *  ...  NaN  NaN
#
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 0      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...
# 75288  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75289  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75290  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75291  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75292  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [75293 rows x 1001 columns]

# %%
prof_df = prof_df[prof_df["Grade"] == "ALL"]

# %%
prof_df
# Out:
# 4     System Code                            System Name School Code  \
# 12            000  Alabama State Department of Education        0000
# 20            000  Alabama State Department of Education        0000
# 28            000  Alabama State Department of Education        0000
# 36            000  Alabama State Department of Education        0000
# 44            000  Alabama State Department of Education        0000
# ...           ...                                    ...         ...
# 75276         810          Magic City Acceptance Academy          10
# 75280         810          Magic City Acceptance Academy          10
# 75284         810          Magic City Acceptance Academy          10
# 75288         810          Magic City Acceptance Academy          10
# 75292         810          Magic City Acceptance Academy          10
#
# 4                                School Name Subject  \
# 12     Alabama State Department of Education     ELA
# 20     Alabama State Department of Education    Math
# 28     Alabama State Department of Education     ELA
# 36     Alabama State Department of Education    Math
# 44     Alabama State Department of Education     ELA
# ...                                      ...     ...
# 75276          Magic City Acceptance Academy    Math
# 75280          Magic City Acceptance Academy     ELA
# 75284          Magic City Acceptance Academy    Math
# 75288          Magic City Acceptance Academy     ELA
# 75292          Magic City Acceptance Academy    Math
#
# 4                                        Test Type Grade  \
# 12                            Alternate Assessment   ALL
# 20                            Alternate Assessment   ALL
# 28     Alternate Assessment Without Accommodations   ALL
# 36     Alternate Assessment Without Accommodations   ALL
# 44        Alternate Assessment With Accommodations   ALL
# ...                                            ...   ...
# 75276                           Regular Assessment   ALL
# 75280    Regular Assessment Without Accommodations   ALL
# 75284    Regular Assessment Without Accommodations   ALL
# 75288       Regular Assessment With Accommodations   ALL
# 75292       Regular Assessment With Accommodations   ALL
#
# 4     ALL Category Only ***% Proficient Percent Of All Students Tested  \
# 12                                28.89                           1.19
# 20                                20.29                           1.19
# 28                                29.75                           0.94
# 36                                20.43                           0.83
# 44                                25.64                           0.25
# ...                                 ...                            ...
# 75276                             18.18                           8.33
# 75280                               NaN                           2.29
# 75284                             33.33                           2.27
# 75288                              37.5                           6.11
# 75292                              12.5                           6.06
#
# 4     Total Students Tested  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  \
# 12                     4493  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20                     4485  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 28                     3553  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 36                     3152  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 44                      940  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 75276                    11  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75280                     *  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75284                     *  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75288                     *  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75292                     *  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# 4      NaN
# 12     NaN
# 20     NaN
# 28     NaN
# 36     NaN
# 44     NaN
# ...    ...
# 75276  NaN
# 75280  NaN
# 75284  NaN
# 75288  NaN
# 75292  NaN
#
# [17160 rows x 1001 columns]

# %%
prof_df = prof_df[prof_df["Test Type"] == "Regular Assessment"]

# %%
prof_df
# Out:
# 4     System Code                            System Name School Code  \
# 60            000  Alabama State Department of Education        0000
# 68            000  Alabama State Department of Education        0000
# 156           001                         Autauga County        0000
# 164           001                         Autauga County        0000
# 252           001                         Autauga County        0015
# ...           ...                                    ...         ...
# 75168         808            Breakthrough Charter School          10
# 75224         810          Magic City Acceptance Academy           0
# 75228         810          Magic City Acceptance Academy           0
# 75272         810          Magic City Acceptance Academy          10
# 75276         810          Magic City Acceptance Academy          10
#
# 4                                School Name Subject           Test Type  \
# 60     Alabama State Department of Education     ELA  Regular Assessment
# 68     Alabama State Department of Education    Math  Regular Assessment
# 156                           Autauga County     ELA  Regular Assessment
# 164                           Autauga County    Math  Regular Assessment
# 252                      Autaugaville School     ELA  Regular Assessment
# ...                                      ...     ...                 ...
# 75168            Breakthrough Charter School    Math  Regular Assessment
# 75224          Magic City Acceptance Academy     ELA  Regular Assessment
# 75228          Magic City Acceptance Academy    Math  Regular Assessment
# 75272          Magic City Acceptance Academy     ELA  Regular Assessment
# 75276          Magic City Acceptance Academy    Math  Regular Assessment
#
# 4     Grade ALL Category Only ***% Proficient Percent Of All Students Tested  \
# 60      ALL                             13.66                          11.81
# 68      ALL                               6.9                          11.88
# 156     ALL                             11.32                          11.03
# 164     ALL                              7.06                          11.08
# 252     ALL                              9.38                          24.06
# ...     ...                               ...                            ...
# 75168   ALL                               0.0                           7.25
# 75224   ALL                             54.55                            8.4
# 75228   ALL                             18.18                           8.33
# 75272   ALL                             54.55                            8.4
# 75276   ALL                             18.18                           8.33
#
# 4     Total Students Tested  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  \
# 60                    44491  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 68                    44889  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 156                     521  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 164                     524  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 252                      32  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 75168                     *  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75224                    11  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75228                    11  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75272                    11  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 75276                    11  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# 4      NaN
# 60     NaN
# 68     NaN
# 156    NaN
# 164    NaN
# 252    NaN
# ...    ...
# 75168  NaN
# 75224  NaN
# 75228  NaN
# 75272  NaN
# 75276  NaN
#
# [2860 rows x 1001 columns]

# %%
prof_df["ALL Category Only ***% Proficient"] = pd.to_numeric(prof_df["ALL Category Only ***% Proficient"], errors="coerce")

average_scores = prof_df.groupby("System Name")["ALL Category Only ***% Proficient"].mean().reset_index()

average_scores
# Out:
# C:\Users\jimmy\AppData\Local\Temp\ipykernel_21456\2716741044.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                System Name  ALL Category Only ***% Proficient
# 0    Alabama State Department of Education                          10.280000
# 1                           Alabaster City                          17.901667
# 2                         Albertville City                           5.070000
# 3                           Alexander City                           6.562000
# 4                           Andalusia City                           9.215000
# ..                                     ...                                ...
# 141                      Washington County                           5.580000
# 142                          Wilcox County                           1.172000
# 143                          Winfield City                           8.497500
# 144                         Winston County                          12.155000
# 145                             i3 Academy                           4.473333
#
# [146 rows x 2 columns]

# %%
average_scores = average_scores.rename(columns={"System Name" : "NAME", "ALL Category Only ***% Proficient": "Average Assessment Proficiency"})

# %%
average_scores
# Out:
#                                       NAME  Average Assessment Proficiency
# 0    Alabama State Department of Education                       10.280000
# 1                           Alabaster City                       17.901667
# 2                         Albertville City                        5.070000
# 3                           Alexander City                        6.562000
# 4                           Andalusia City                        9.215000
# ..                                     ...                             ...
# 141                      Washington County                        5.580000
# 142                          Wilcox County                        1.172000
# 143                          Winfield City                        8.497500
# 144                         Winston County                       12.155000
# 145                             i3 Academy                        4.473333
#
# [146 rows x 2 columns]

# %%
average_scores.to_csv("alabama_proficiency_scores.csv", index=False)

# %%
alabama_final_df = pd.merge(df, average_scores, on='NAME', how='left')

# %%
alabama_final_df
# Out:
#     STATE                    NAME        LAT        LON  \
# 0      AL  Alabama Youth Services  32.376397 -86.084642
# 1      AL        Albertville City  34.282186 -86.223627
# 2      AL         Marshall County  34.305770 -86.286958
# 3      AL             Hoover City  33.406200 -86.766900
# 4      AL            Madison City  34.686721 -86.745741
# ..    ...                     ...        ...        ...
# 180    AL           Walker County  33.834179 -87.274959
# 181    AL       Washington County  31.465862 -88.257989
# 182    AL           Wilcox County  32.003296 -87.290119
# 183    AL           Winfield City  33.933197 -87.811801
# 184    AL          Winston County  34.146071 -87.402788
#
#      Average Assessment Proficiency
# 0                               NaN
# 1                          5.070000
# 2                          6.711818
# 3                         27.817500
# 4                         34.288333
# ..                              ...
# 180                        7.265882
# 181                        5.580000
# 182                        1.172000
# 183                        8.497500
# 184                       12.155000
#
# [185 rows x 5 columns]

# %%
conn.close()
